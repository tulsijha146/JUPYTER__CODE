# %%
print("Hello")
# Out:
# Hello

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from numpy.random import randn,randint,uniform,sample

# %%
df=pd.DataFrame(randn(1000),index=pd.date_range('2020-05-29',periods=1000),columns=['value'])
ts=pd.Series(randn(1000),index=pd.date_range('2020-05-29',periods=1000))
df.head()
# Out:
#                value
# 2020-05-29  0.455302
# 2020-05-30 -1.205782
# 2020-05-31 -0.051519
# 2020-06-01  0.023176
# 2020-06-02  0.288797

# %%
df['value']=df['value'].cumsum()
df.head()
# Out:
#                value
# 2020-05-29  0.455302
# 2020-05-30 -0.295179
# 2020-05-31 -1.097179
# 2020-06-01 -1.876003
# 2020-06-02 -2.366031

# %%
df.plot()

# %%
df=pd.DataFrame(randn(100),columns=['value'])
df
# Out:
#        value
# 0   1.036861
# 1  -1.269535
# 2   0.055281
# 3  -0.019149
# 4   0.441570
# ..       ...
# 95  0.243300
# 96  0.668875
# 97 -1.032071
# 98  0.226209
# 99  0.557092
#
# [100 rows x 1 columns]

# %%
df=pd.DataFrame(randn(1000),index=pd.date_range('2020-05-29',periods=1000),columns=['value'])
df
# Out:
#                value
# 2020-05-29  1.034473
# 2020-05-30 -0.416616
# 2020-05-31  0.419020
# 2020-06-01 -2.040375
# 2020-06-02  1.696860
# ...              ...
# 2023-02-18  0.133694
# 2023-02-19 -0.197862
# 2023-02-20  0.949418
# 2023-02-21  0.263848
# 2023-02-22  2.341599
#
# [1000 rows x 1 columns]

# %%
df.plot()

# %%
df.plot(kind='line')

# %%
iris=sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris.plot()

# %%
ax=iris.plot(figsize=(15,8),title='Iris Dataset')
ax.set_xlabel('X Axis')
ax.set_ylabel('Y Axis')
# Out:
# Text(0, 0.5, 'Y Axis')

# %%
df=iris.drop(['species'],axis=1)

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
df.iloc[0]
# Out:
# sepal_length    5.1
# sepal_width     3.5
# petal_length    1.4
# petal_width     0.2
# Name: 0, dtype: float64

# %%
df.plot(kind='bar')

# %%
df.iloc[0].plot(kind='bar')

# %%
df.iloc[0].plot.bar()

# %%
titanic=sns.load_dataset('titanic')
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
titanic['pclass'].plot()

# %%
titanic['age'].plot.bar()

# %%
titanic['pclass'].plot(kind='bar')

# %%
df=pd.DataFrame(randn(10,4),columns=['a','b','c','d'])

# %%
df.head(10)
# Out:
#           a         b         c         d
# 0 -0.283926 -0.881786 -0.368665  0.168058
# 1 -1.523306  1.544201 -1.336596 -0.675124
# 2  0.881317  0.189994 -1.191708  0.849708
# 3  1.332038  0.822595  0.944535 -0.312767
# 4  0.001569  0.131462  1.929453 -1.714960
# 5 -1.089529 -1.450030 -1.193155 -0.116109
# 6  0.595451 -0.463579  1.130404 -0.915345
# 7  0.443592 -0.315369  0.092395 -0.727262
# 8 -1.132253 -0.283244 -0.868945 -0.244515
# 9  0.513249  0.719379  0.606550  0.158175

# %%
df.plot.bar()

# %%
df.plot.barh()

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris['sepal_length'].plot.hist()

# %%
iris['sepal_length'].plot(kind='hist',stacked=False,bins=10)

# %%
iris['sepal_length'].plot(kind='hist',stacked=True,bins=100)

# %%
iris['sepal_length'].plot.hist(stacked=True,bins=50,orientation='horizontal',color='black')

# %%
iris['sepal_width'].diff()
# Out:
# 0      NaN
# 1     -0.5
# 2      0.2
# 3     -0.1
# 4      0.5
#       ...
# 145   -0.3
# 146   -0.5
# 147    0.5
# 148    0.4
# 149   -0.4
# Name: sepal_width, Length: 150, dtype: float64

# %%
iris['sepal_width'].plot(kind='hist',stacked=True,bins=50)

# %%
#alpha=density of the color
#diff()is the difference between prevoius data and next data
df.diff().hist(color='r',alpha=0.9,figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000010E39E32888>,
# ...
#       dtype=object)

# %%
#scatter graph=diff b/w one cross with anothe cross in terms of dot(.)
iris.plot.scatter(x='sepal_length',y='petal_length')

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris.plot.scatter(x='sepal_length',y='petal_length',c='sepal_width')

# %%
df=iris

# %%
ax=df.plot.scatter(x='sepal_length',y='petal_length',label='Length')
df.plot.scatter(x='sepal_width',y='petal_width',label='Width',ax=ax,color='r')

# %%
df.plot.scatter(x='sepal_length',y='petal_length',label='Length')

# %%
df.plot.scatter(x='sepal_width',y='petal_width',label='Width',color='r')

# %%
ax=df.plot.scatter(x='sepal_length',y='petal_length',label='Length')
df.plot.scatter(x='sepal_width',y='petal_width',label='Width',ax=ax,color='r')

# %%
df.plot.scatter(x='sepal_length',y='petal_length',c='sepal_width',s=500)

# %%
df.plot.hexbin(x='sepal_length',y='petal_length',gridsize=5,C='sepal_width')

# %%
df=iris.drop(['species'],axis=1)
d=df.iloc[0]
d
# Out:
# sepal_length    5.1
# sepal_width     3.5
# petal_length    1.4
# petal_width     0.2
# Name: 0, dtype: float64

# %%
d.plot.pie(figsize=(10,8))

# %%
d=df.head(3).T

# %%
d
# Out:
#                 0    1    2
# sepal_length  5.1  4.9  4.7
# sepal_width   3.5  3.0  3.2
# petal_length  1.4  1.4  1.3
# petal_width   0.2  0.2  0.2

# %%
d.plot.pie(subplots=True,figsize=(15,15))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000010E3C8CD948>,
# ...
#       dtype=object)

# %%
from pandas.plotting import scatter_matrix

# %%
scatter_matrix(df,figsize=(10,10),color='r')
plt.show()

# %%
scatter_matrix(df,figsize=(10,10),color='r',diagonal='kde')
plt.show()

# %%
ts.plot(style='r--',legend=True,label='Series')

# %%
df.plot(legend=True,figsize=(10,5),logy=True)

# %%
df.plot(subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000010E43807748>,
# ...
#       dtype=object)

# %%
df.plot()

# %%
df.plot(subplots=True,sharex=False,figsize=(16,8),layout=(2,3))
plt.tight_layout()
