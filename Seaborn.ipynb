# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1-5c8b0c836a28> in <module>
# ----> 1 import seaborn as sns
#       2 import pandas as pd
#       3 import numpy as np
#       4 import matplotlib.pyplot as plt
#       5 get_ipython().run_line_magic('matplotlib', 'inline')
#
# ~\anaconda3\lib\site-packages\seaborn\__init__.py in <module>
#       4
#       5 # Import seaborn objects
# ----> 6 from .rcmod import *
#       7 from .utils import *
#       8 from .palettes import *
#
# ~\anaconda3\lib\site-packages\seaborn\rcmod.py in <module>
#       4 import matplotlib as mpl
#       5 import warnings
# ----> 6 from . import palettes, _orig_rc_params
#       7
#       8
#
# ~\anaconda3\lib\site-packages\seaborn\palettes.py in <module>
#       8 from .external import husl
#       9
# ---> 10 from .utils import desaturate, set_hls_values, get_color_cycle
# ...

# %%
sns.set(style='darkgrid')

# %%
tips=sns.load_dataset('tips')
tips['size']
# Out:
# 0      2
# 1      3
# 2      3
# 3      2
# 4      4
#       ..
# 239    3
# 240    2
# 241    2
# 242    2
# 243    2
# Name: size, Length: 244, dtype: int64

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.relplot(x='total_bill',y='tip',data=tips)

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips['smoker'].value_counts()
# Out:
# No     151
# Yes     93
# Name: smoker, dtype: int64

# %%
sns.relplot(x='total_bill',y='tip',data=tips,hue='smoker')#,hue='smoker',data='tips')

# %%
sns.relplot(x='total_bill',y='tip',data=tips,hue='smoker',style='time')

# %%
sns.relplot(x='total_bill',y='tip',data=tips,style='size',hue='smoker')

# %%
sns.relplot(x='total_bill',y='tip',data=tips,style='size',hue='size')

# %%
sns.relplot(x='total_bill',y='tip',data=tips,hue='smoker',style='time',size='size')

# %%
sns.relplot(x='total_bill',y='tip',data=tips,size='tip')

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
from numpy.random import randn

# %%
df=pd.DataFrame(dict(time=np.arange(500),value=randn(500).cumsum()))

# %%
df.head()
# Out:
#    time     value
# 0     0 -1.104828
# 1     1  0.833470
# 2     2 -1.297473
# 3     3 -3.024523
# 4     4 -4.049574

# %%
sns.relplot(x='time',y='value',data=df)

# %%
sns.relplot(x='time',y='value',data=df,kind='line',sort=True)

# %%
fmri=sns.load_dataset('fmri')
fmri.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
sns.relplot(x='timepoint',y='signal',data=fmri)

# %%
fmri
# Out:
#      subject  timepoint event    region    signal
# 0        s13         18  stim  parietal -0.017552
# 1         s5         14  stim  parietal -0.080883
# 2        s12         18  stim  parietal -0.081033
# 3        s11         18  stim  parietal -0.046134
# 4        s10         18  stim  parietal -0.037970
# ...      ...        ...   ...       ...       ...
# 1059      s0          8   cue   frontal  0.018165
# 1060     s13          7   cue   frontal -0.029130
# 1061     s12          7   cue   frontal -0.004939
# 1062     s11          7   cue   frontal -0.025367
# 1063      s0          0   cue  parietal -0.006899
#
# [1064 rows x 5 columns]

# %%
sns.relplot(x='event',y='region',data=fmri)

# %%
sns.relplot(x='subject',y='signal',data=fmri,kind='line')

# %%
sns.relplot(x='timepoint',y='signal',data=fmri,ci='sd',kind='line')

# %%
fmri
# Out:
#      subject  timepoint event    region    signal
# 0        s13         18  stim  parietal -0.017552
# 1         s5         14  stim  parietal -0.080883
# 2        s12         18  stim  parietal -0.081033
# 3        s11         18  stim  parietal -0.046134
# 4        s10         18  stim  parietal -0.037970
# ...      ...        ...   ...       ...       ...
# 1059      s0          8   cue   frontal  0.018165
# 1060     s13          7   cue   frontal -0.029130
# 1061     s12          7   cue   frontal -0.004939
# 1062     s11          7   cue   frontal -0.025367
# 1063      s0          0   cue  parietal -0.006899
#
# [1064 rows x 5 columns]

# %%
sns.relplot(x='timepoint',y='signal',kind='line',hue='event',data=fmri)

# %%
fmri.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
sns.relplot(x='timepoint',y='signal',data=fmri,kind='line',style='event',hue='region')

# %%
df=pd.DataFrame(dict(time=pd.date_range('2020-05-31',periods=1000),value=randn(1000).cumsum()))

# %%
df.head()
# Out:
#         time     value
# 0 2020-05-31  0.265632
# 1 2020-06-01  0.373663
# 2 2020-06-02  0.791413
# 3 2020-06-03  1.480745
# 4 2020-06-04  2.168598

# %%
g=sns.relplot(x='time',y='value',data=df,kind='line')
g.fig.autofmt_xdate()

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.relplot(x='total_bill',y='tip',data=tips,hue='smoker',col='time')

# %%
sns.relplot(x='total_bill',y='tip',data=tips,col='size',hue='smoker')

# %%
sns.relplot(x='total_bill',y='tip',data=tips,hue='smoker',col_wrap=3,height=3,col='size')

# %%
sns.scatterplot(x='total_bill',y='tip',data=tips)

# %%
iris=sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.scatterplot(x='sepal_length',y='petal_length',data=iris)

# %%
a=iris['sepal_length']
b=iris['petal_length']

# %%
sns.scatterplot(x=a,y=b)

# %%
sns.scatterplot(x=iris['sepal_length'],y=iris['petal_length'])

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
titanic=sns.load_dataset('titanic')
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.catplot(x='day',y='total_bill',data=tips)

# %%
sns.catplot(x='total_bill',y='day',data=tips)

# %%
sns.catplot(x='total_bill',y='day',data=tips,jitter=False)

# %%
sns.catplot(x='total_bill',y='day',data=tips,hue='size')

# %%
sns.catplot(x='total_bill',y='day',data=tips,hue='size',kind='swarm')#,kind='line')

# %%
sns.catplot(x='day',y='total_bill',data=tips,hue='size',kind='swarm')#,kind='line')

# %%
sns.catplot(x='smoker',y='tip',data=tips,order=['No','Yes'])

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.catplot(x='day',y='tip',kind='box',data=tips,hue='sex')

# %%
sns.catplot(x='day',y='total_bill',kind='box',data=tips,hue='sex',dodge=False)

# %%
diamonds=sns.load_dataset('diamonds')

# %%
diamonds.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
sns.catplot(x='color',y='price',kind='boxen',data=diamonds.sort_values('color'))

# %%
sns.catplot(x='color',y='price',kind='boxen',data=diamonds)

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.catplot(x='total_bill',y='tip',data=tips,kind='violin',hue='sex',split=True,)

# %%
sns.catplot(x='total_bill',y='day',data=tips,kind='violin',hue='sex',split=True,)

# %%
g=sns.catplot(x='day',y='total_bill',data=tips,kind='violin',hue='sex',inner=None,split=True,)
sns.swarmplot(x='day',y='total_bill',color='k',size=5,ax=g.ax,data=tips)

# %%
sns.swarmplot(x='day',y='total_bill',color='k',size=5,ax=g.ax,data=tips)

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
fmri
# Out:
#      subject  timepoint event    region    signal
# 0        s13         18  stim  parietal -0.017552
# 1         s5         14  stim  parietal -0.080883
# 2        s12         18  stim  parietal -0.081033
# 3        s11         18  stim  parietal -0.046134
# 4        s10         18  stim  parietal -0.037970
# ...      ...        ...   ...       ...       ...
# 1059      s0          8   cue   frontal  0.018165
# 1060     s13          7   cue   frontal -0.029130
# 1061     s12          7   cue   frontal -0.004939
# 1062     s11          7   cue   frontal -0.025367
# 1063      s0          0   cue  parietal -0.006899
#
# [1064 rows x 5 columns]

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.catplot(x='deck',kind='count',palette='ch:0.01',data=titanic,hue='class')

# %%
#Distribution plot
x=randn(100)
x
# Out:
# array([ 0.53091998,  1.17508313,  1.29850789,  0.9575074 , -1.37030215,
#        -0.19625388, -2.22860066,  0.48424677,  2.45603433,  0.98105551,
#        -1.3009785 ,  1.62256885, -0.87267809,  0.49816797,  1.65265746,
#         1.32410609, -0.37385153,  0.8384762 ,  1.07835019,  1.08214032,
#         0.39283261, -0.84910145,  1.3044059 , -0.68489777,  1.18781765,
#         1.18208088,  1.91782489, -0.48691605, -0.27016754,  0.32433417,
#         0.01585761, -0.60454562, -1.25211037,  0.41017074, -0.08268978,
#        -0.08186372,  0.01384201, -0.64794715,  1.33548378, -0.5409452 ,
#        -2.35504602,  0.72386241, -1.85536919,  0.53320111,  1.11501115,
#        -1.21503788,  0.60031526, -1.01356536,  1.02555798,  0.47048445,
#         1.44194852, -0.03164647,  1.52138712,  0.70352401,  0.20326086,
#        -0.09321459, -0.04122029, -1.08433433, -1.79819421, -0.40791714,
#        -0.24717535, -1.90922874,  0.44784512, -0.03732587, -1.48445684,
# ...

# %%
sns.distplot(x)

# %%
x=randn(100000)
x
# Out:
# array([ 1.02139825,  1.06733534, -0.3019463 , ..., -1.23079652,
#         1.69891681,  1.18384877])

# %%
sns.distplot(x)

# %%
titanic['age']
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: age, Length: 891, dtype: float64

# %%
x=randn(1000)
sns.distplot(x,hist=True,rug=True,bins=10)

# %%
x=tips["total_bill"]
y=tips['tip']

# %%
sns.jointplot(x=x,y=y)

# %%
sns.jointplot(x=x,y=y,kind='kde')

# %%
np.array(titanic['age'])
# Out:
# array([22.  , 38.  , 26.  , 35.  , 35.  ,   nan, 54.  ,  2.  , 27.  ,
#        14.  ,  4.  , 58.  , 20.  , 39.  , 14.  , 55.  ,  2.  ,   nan,
#        31.  ,   nan, 35.  , 34.  , 15.  , 28.  ,  8.  , 38.  ,   nan,
#        19.  ,   nan,   nan, 40.  ,   nan,   nan, 66.  , 28.  , 42.  ,
#          nan, 21.  , 18.  , 14.  , 40.  , 27.  ,   nan,  3.  , 19.  ,
#          nan,   nan,   nan,   nan, 18.  ,  7.  , 21.  , 49.  , 29.  ,
#        65.  ,   nan, 21.  , 28.5 ,  5.  , 11.  , 22.  , 38.  , 45.  ,
#         4.  ,   nan,   nan, 29.  , 19.  , 17.  , 26.  , 32.  , 16.  ,
#        21.  , 26.  , 32.  , 25.  ,   nan,   nan,  0.83, 30.  , 22.  ,
#        29.  ,   nan, 28.  , 17.  , 33.  , 16.  ,   nan, 23.  , 24.  ,
#        29.  , 20.  , 46.  , 26.  , 59.  ,   nan, 71.  , 23.  , 34.  ,
#        34.  , 28.  ,   nan, 21.  , 33.  , 37.  , 28.  , 21.  ,   nan,
#        38.  ,   nan, 47.  , 14.5 , 22.  , 20.  , 17.  , 21.  , 70.5 ,
# ...

# %%
sns.distplot(np.array(titanic[titanic.age.notnull()]['age']))

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.set()
sns.jointplot(x=x,y=y,kind='hex')

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.pairplot(iris)

# %%
sns.lmplot(x='total_bill',y='tip',data=tips)
