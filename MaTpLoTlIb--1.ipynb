# %%
import pandas as pd
import numpy as np
#%matplotlib inline

# %%
import numpy as np
import pandas as pd
#import seaborn as sns
#import matplotlib.pyplot as plt
#%matplotlib inline

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-0f327634ac60> in <module>
# ----> 1 import seaborn as sns
#       2 import matplotlib.pyplot as plt
#       3 get_ipython().run_line_magic('matplotlib', 'inline')
#
# ~\anaconda3\lib\site-packages\seaborn\__init__.py in <module>
#       4
#       5 # Import seaborn objects
# ----> 6 from .rcmod import *
#       7 from .utils import *
#       8 from .palettes import *
#
# ~\anaconda3\lib\site-packages\seaborn\rcmod.py in <module>
#       4 import matplotlib as mpl
#       5 import warnings
# ----> 6 from . import palettes, _orig_rc_params
#       7
#       8
#
# ~\anaconda3\lib\site-packages\seaborn\palettes.py in <module>
#       8 from .external import husl
#       9
# ---> 10 from .utils import desaturate, set_hls_values, get_color_cycle
#      11 from .colors import xkcd_rgb, crayons
#      12
#
# ...

# %%
from numpy.random import randn,randint,uniform,sample

# %%
df=pd.DataFrame(randn(1000),index=pd.date_range('2020-09-22',periods=1000),columns=['value'])
ts=pd.Series(randn(1000),index=pd.date_range('2020-09-22',periods=1000))
df.head()
# Out:
#                value
# 2020-09-22 -0.783290
# 2020-09-23 -0.167105
# 2020-09-24  0.859172
# 2020-09-25  1.092364
# 2020-09-26 -1.250621

# %%
ts
# Out:
# 2020-09-22    0.254642
# 2020-09-23    0.914050
# 2020-09-24   -1.443382
# 2020-09-25    0.564313
# 2020-09-26   -1.906082
#                 ...
# 2023-06-14   -1.360702
# 2023-06-15   -2.146306
# 2023-06-16    0.619153
# 2023-06-17    1.574992
# 2023-06-18   -1.112400
# Freq: D, Length: 1000, dtype: float64

# %%
df
# Out:
#                value
# 2020-09-22 -0.783290
# 2020-09-23 -0.167105
# 2020-09-24  0.859172
# 2020-09-25  1.092364
# 2020-09-26 -1.250621
# ...              ...
# 2023-06-14  1.251052
# 2023-06-15 -1.682717
# 2023-06-16  0.513427
# 2023-06-17 -0.962983
# 2023-06-18  0.344016
#
# [1000 rows x 1 columns]

# %%
ts
# Out:
# 2020-09-22    0.254642
# 2020-09-23    0.914050
# 2020-09-24   -1.443382
# 2020-09-25    0.564313
# 2020-09-26   -1.906082
#                 ...
# 2023-06-14   -1.360702
# 2023-06-15   -2.146306
# 2023-06-16    0.619153
# 2023-06-17    1.574992
# 2023-06-18   -1.112400
# Freq: D, Length: 1000, dtype: float64

# %%
ts.plot()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-31-8a34b37f0ce9> in <module>
# ----> 1 ts.plot()
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     867
#     868     def __call__(self, *args, **kwargs):
# --> 869         plot_backend = _get_plot_backend(kwargs.pop("backend", None))
#     870
#     871         x, y, kind, kwargs = self._get_call_args(
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_core.py in _get_plot_backend(backend)
#    1776         # we need to attempt an import here to raise an ImportError if needed.
#    1777         try:
# -> 1778             import pandas.plotting._matplotlib as module
#    1779         except ImportError:
#    1780             raise ImportError(
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\__init__.py in <module>
# ...

# %%
type(df),type(ts)
# Out:
# (pandas.core.frame.DataFrame, pandas.core.series.Series)

# %%
ts.plot(figsize=(15,5))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-33-7d7a90c52c9c> in <module>
# ----> 1 ts.plot(figsize=(15,5))
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     867
#     868     def __call__(self, *args, **kwargs):
# --> 869         plot_backend = _get_plot_backend(kwargs.pop("backend", None))
#     870
#     871         x, y, kind, kwargs = self._get_call_args(
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_core.py in _get_plot_backend(backend)
#    1776         # we need to attempt an import here to raise an ImportError if needed.
#    1777         try:
# -> 1778             import pandas.plotting._matplotlib as module
#    1779         except ImportError:
#    1780             raise ImportError(
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\__init__.py in <module>
# ...

# %%
ts
# Out:
# 2020-09-22    0.462685
# 2020-09-23    0.103606
# 2020-09-24    0.009536
# 2020-09-25   -0.397585
# 2020-09-26    0.460242
#                 ...
# 2023-06-14    0.119036
# 2023-06-15    0.444075
# 2023-06-16   -0.681769
# 2023-06-17   -0.769594
# 2023-06-18    1.335143
# Freq: D, Length: 1000, dtype: float64

# %%
#cumcum-->community sum-->summation of previous number nd the current number
ts=ts.cumsum()
ts.head()
# Out:
# 2020-09-22    0.462685
# 2020-09-23    0.566291
# 2020-09-24    0.575827
# 2020-09-25    0.178242
# 2020-09-26    0.638484
# Freq: D, dtype: float64

# %%
ts.plot(figsize=(10,5))

# %%
plt.plot(ts)

# %%
df.cumsum()
# Out:
#                 value
# 2020-09-22  -0.621288
# 2020-09-23  -0.960839
# 2020-09-24  -1.110322
# 2020-09-25  -1.741187
# 2020-09-26  -1.630636
# ...               ...
# 2023-06-14  13.995775
# 2023-06-15  15.520511
# 2023-06-16  17.568702
# 2023-06-17  17.653336
# 2023-06-18  18.376080
#
# [1000 rows x 1 columns]

# %%
df.plot()

# %%
ts=ts.cumsum()
ts.plot(figsize=(5,5))

# %%
iris=sns.load_dataset('iris')
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
ax=iris.plot(figsize=(15,8),title='Iris DataSet')
ax

# %%
ax.set_xlabel('X Axis')
ax.set_ylabel('Y Axis')
# Out:
# Text(3.200000000000017, 0.5, 'Y Axis')

# %%
ax=iris.plot(figsize=(15,8),title='Iris DataSet')
ax.set_xlabel('X Axis')
ax.set_ylabel('Y Axis')
# Out:
# Text(0, 0.5, 'Y Axis')

# %%
ts.plot(kind='bar')

# %%
df.plot(kind='bar')

# %%
df
# Out:
#                value
# 2020-09-22 -0.621288
# 2020-09-23 -0.339551
# 2020-09-24 -0.149483
# 2020-09-25 -0.630865
# 2020-09-26  0.110551
# ...              ...
# 2023-06-14 -0.154921
# 2023-06-15  1.524736
# 2023-06-16  2.048191
# 2023-06-17  0.084635
# 2023-06-18  0.722743
#
# [1000 rows x 1 columns]

# %%
df=iris.drop(['species'],axis=1)
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
df.iloc[0]
# Out:
# sepal_length    5.1
# sepal_width     3.5
# petal_length    1.4
# petal_width     0.2
# Name: 0, dtype: float64

# %%
df.iloc[0].plot(kind='bar')

# %%
titanic=sns.load_dataset('titanic')
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
titanic['pclass']
# Out:
# 0      3
# 1      1
# 2      3
# 3      1
# 4      3
#       ..
# 886    2
# 887    1
# 888    3
# 889    1
# 890    3
# Name: pclass, Length: 891, dtype: int64

# %%
titanic['pclass'].plot(kind='bar')

# %%
df=pd.DataFrame(randn(10,4),columns=['a','b','c','d'])
df
# Out:
#           a         b         c         d
# 0  1.261689  1.169912 -0.907564  1.449822
# 1 -0.019456  0.421297  0.442390  0.678088
# 2  0.513887 -0.091813  0.439478  0.057466
# 3  1.071477  0.131574  1.251629  0.391984
# 4  0.727398 -0.149285 -1.080586 -0.481694
# 5  0.551607  0.531201  0.297690  0.428719
# 6  1.232136 -0.639944 -0.336666 -0.281722
# 7  1.072600  1.178983 -0.006860  0.076086
# 8 -1.429669  0.292575 -1.332945  1.394498
# 9 -1.632877 -0.894734 -1.034867  0.807263

# %%
df.head(10)
# Out:
#           a         b         c         d
# 0  1.261689  1.169912 -0.907564  1.449822
# 1 -0.019456  0.421297  0.442390  0.678088
# 2  0.513887 -0.091813  0.439478  0.057466
# 3  1.071477  0.131574  1.251629  0.391984
# 4  0.727398 -0.149285 -1.080586 -0.481694
# 5  0.551607  0.531201  0.297690  0.428719
# 6  1.232136 -0.639944 -0.336666 -0.281722
# 7  1.072600  1.178983 -0.006860  0.076086
# 8 -1.429669  0.292575 -1.332945  1.394498
# 9 -1.632877 -0.894734 -1.034867  0.807263

# %%
df.plot.bar()

# %%
df.plot(kind='bar')

# %%
df.plot(kind='hist')

# %%
df.plot.barh()

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
iris.plot(kind='hist')

# %%
iris['sepal_width']
# Out:
# 0      3.5
# 1      3.0
# 2      3.2
# 3      3.1
# 4      3.6
#       ...
# 145    3.0
# 146    2.5
# 147    3.0
# 148    3.4
# 149    3.0
# Name: sepal_width, Length: 150, dtype: float64

# %%
iris['sepal_width'].plot.hist()

# %%
iris.plot.hist()

# %%
iris.plot(kind='hist',stacked=True,bins=50)

# %%
iris.plot(kind='hist',bins=50)

# %%
iris.plot(kind='hist',stacked=True,bins=50,orientation='horizontal')

# %%
iris['sepal_width']
# Out:
# 0      3.5
# 1      3.0
# 2      3.2
# 3      3.1
# 4      3.6
#       ...
# 145    3.0
# 146    2.5
# 147    3.0
# 148    3.4
# 149    3.0
# Name: sepal_width, Length: 150, dtype: float64

# %%
iris['sepal_width'].diff().plot(kind='hist',stacked=True,bins=50)

# %%
df=iris.drop(['species'],axis=1)
df.diff().head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           NaN          NaN           NaN          NaN
# 1          -0.2         -0.5           0.0          0.0
# 2          -0.2          0.2          -0.1          0.0
# 3          -0.1         -0.1           0.2          0.0
# 4           0.4          0.5          -0.1          0.0

# %%
df.diff().hist(color='b',alpha=0.1,figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000020B5817A908>,
# ...
#       dtype=object)

# %%
#TASK
'''
1.download--titanic data-set
2.plot a graph for fare class variation
3.try to run survived in histogram

'''
# Out:
# '\n1.download--titanic data-set\n2.plot a graph for fare class variation\n3.try to run survived in histogram\n\n'

# %%
#df=pd.read_csv('D:\\ineoron MLDL\\DATA_SET')
#df

# %%
df1=pd.read_csv('C:\\Users\\Raushan\\Downloads\\train.csv')
df1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df1.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df1['Fare']
# Out:
# 0       7.2500
# 1      71.2833
# 2       7.9250
# 3      53.1000
# 4       8.0500
#         ...
# 886    13.0000
# 887    30.0000
# 888    23.4500
# 889    30.0000
# 890     7.7500
# Name: Fare, Length: 891, dtype: float64

# %%
#1
df1['Fare'].plot()

# %%
df1['Fare'].plot(figsize=(10,5))

# %%
df1['Survived']
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %%
#2
df1['Survived'].plot(kind='hist')

# %%
df1['Survived'].plot(kind='hist',title='plot for survived column')

# %%
df.diff().hist(color='b',alpha=0.9,figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000020B59588888>,
# ...
#       dtype=object)

# %%
df.plot.scatter(x='sepal_length',y='petal_length')

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
iris.plot(x='sepal_length',y='petal_length')

# %%
iris.plot.scatter(x='sepal_length',y='petal_length')

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
#df

# %%
#c is nothing but it define the color range in b/ x and y co_ordiante
iris.plot.scatter(x='sepal_length',y='petal_length',c='sepal_width')

# %%
iris.plot.scatter(x='sepal_length',y='petal_length',c='sepal_width',s=10000)

# %%
iris.plot.hexbin(x='sepal_length',y='petal_length',C='sepal_width',gridsize=5)

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
d=iris.iloc[0]
d
# Out:
# sepal_length       5.1
# sepal_width        3.5
# petal_length       1.4
# petal_width        0.2
# species         setosa
# Name: 0, dtype: object

# %%
d.plot.pie(figsize=(10,10))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-73-8cfc49b4597d> in <module>
# ----> 1 d.plot.pie(figsize=(10,10))
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_core.py in pie(self, **kwargs)
#    1416         ):
#    1417             raise ValueError("pie requires either y column or 'subplots=True'")
# -> 1418         return self(kind="pie", **kwargs)
#    1419
#    1420     def scatter(self, x, y, s=None, c=None, **kwargs):
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     845                     data.columns = label_name
#     846
# --> 847         return plot_backend.plot(data, kind=kind, **kwargs)
#     848
#     849     __call__.__doc__ = __doc__
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\__init__.py in plot(data, kind, **kwargs)
#      58                 ax = plt.gca()
# ...

# %%
iris.head(3)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa

# %%
d=iris.head(3).T
d
# Out:
#                    0       1       2
# sepal_length     5.1     4.9     4.7
# sepal_width      3.5       3     3.2
# petal_length     1.4     1.4     1.3
# petal_width      0.2     0.2     0.2
# species       setosa  setosa  setosa

# %%
d.plot.pie(subplots=True,figsize=(10,10))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-76-fd589a2aadb9> in <module>
# ----> 1 d.plot.pie(subplots=True,figsize=(10,10))
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_core.py in pie(self, **kwargs)
#    1416         ):
#    1417             raise ValueError("pie requires either y column or 'subplots=True'")
# -> 1418         return self(kind="pie", **kwargs)
#    1419
#    1420     def scatter(self, x, y, s=None, c=None, **kwargs):
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     845                     data.columns = label_name
#     846
# --> 847         return plot_backend.plot(data, kind=kind, **kwargs)
#     848
#     849     __call__.__doc__ = __doc__
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\__init__.py in plot(data, kind, **kwargs)
#      58                 ax = plt.gca()
# ...

# %%
from pandas.plotting import scatter_matrix

# %%
scatter_matrix(iris,figsize=(8,8),diagonal='kde',color='b')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001C45AB8B848>,
# ...
#       dtype=object)

# %%
scatter_matrix(iris,figsize=(8,8),diagonal='kde',color='b')
plt.show()

# %%
ts
# Out:
# 2020-09-22    4.698491e-01
# 2020-09-23    1.967398e+00
# 2020-09-24    4.339072e+00
# 2020-09-25    6.607126e+00
# 2020-09-26    8.170880e+00
#                   ...
# 2023-06-14   -5.713727e+13
# 2023-06-15   -5.741970e+13
# 2023-06-16   -5.770322e+13
# 2023-06-17   -5.798782e+13
# 2023-06-18   -5.827352e+13
# Freq: D, Length: 1000, dtype: float64

# %%
#KDE--->Kernal Density Esmation

# %%
ts.plot.kde()

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
iris['sepal_length'].plot(kind='kde')

# %%
ts.plot()

# %%
ts.plot(style='r--',label='Series',legend=True)

# %%
ts.plot(style='r->',label='Series',legend=True)

# %%
ts.plot(style='r*',label='Series',legend=True)

# %%
iris.plot(legend=True,figsize=(10,5),logy=True)

# %%
df.plot()

# %%
iris.plot()

# %%
iris.plot(subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000001C45CB8EF48>,
# ...
#       dtype=object)

# %%
iris.plot(subplots=True,sharex=False,layout=(2,3),figsize=(10,8))
plt.tight_layout()

# %%
# importing packages 
import pandas as pd 
import pandas_profiling as pp 
  
  
# dictionary of data 
dct = {'ID': {0: 23, 1: 43, 2: 12, 3: 13,  
              4: 67, 5: 89, 6: 90, 7: 56,  
              8: 34},  
       'Name': {0: 'Ram', 1: 'Deep', 2: 'Yash', 
                3: 'Aman', 4: 'Arjun', 5: 'Aditya', 
                6: 'Divya', 7: 'Chalsea', 
                8: 'Akash' },  
       'Marks': {0: 89, 1: 97, 2: 45, 3: 78, 
                 4: 56, 5: 76, 6: 100, 7: 87, 
                 8: 81},  
       'Grade': {0: 'B', 1: 'A', 2: 'F', 3: 'C', 
                 4: 'E', 5: 'C', 6: 'A', 7: 'B', 
                 8: 'B'} 
      } 
  
# forming dataframe and printing 
data = pd.DataFrame(dct) 
print(data) 
  
# forming ProfileReport and save 
# as output.html file 
profile = pp.ProfileReport(data) 
profile.to_file("output.html")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-6-4a1aef51aabb> in <module>
#       1 # importing packages
#       2 import pandas as pd
# ----> 3 import pandas_profiling as pp
#       4
#       5
#
# ModuleNotFoundError: No module named 'pandas_profiling'
