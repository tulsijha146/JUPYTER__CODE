# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.DataFrame({"A":[1,2,np.nan],"B":[3,np.nan,np.nan],"C":[3,4,5]})
df
# Out:
#      A    B  C
# 0  1.0  3.0  3
# 1  2.0  NaN  4
# 2  NaN  NaN  5

# %%
df['States']='CV AN Nz'.split()
df.set_index('States',inplace=True)

# %%
df
# Out:
#           A    B  C
# States
# CV      1.0  3.0  3
# AN      2.0  NaN  4
# Nz      NaN  NaN  5

# %%
df.dropna()
# Out:
#           A    B  C
# States
# CV      1.0  3.0  3

# %%
df.dropna(axis=1)
# Out:
#         C
# States
# CV      3
# AN      4
# Nz      5

# %%
#Require that many non-NA values.
df.dropna(thresh=2)
# Out:
#           A    B  C
# States
# CV      1.0  3.0  3
# AN      2.0  NaN  4

# %%
data = {'Company':['GOOG','GOOG','MSFT','MSFT','FB','FB'],
       'Person':['Sam','Charlie','Amy','Vanessa','Carl','Sarah'],
       'Sales':[200,120,340,124,243,350]}
df = pd.DataFrame(data)
df
# Out:
#   Company   Person  Sales
# 0    GOOG      Sam    200
# 1    GOOG  Charlie    120
# 2    MSFT      Amy    340
# 3    MSFT  Vanessa    124
# 4      FB     Carl    243
# 5      FB    Sarah    350

# %%
df.describe()
# Out:
#             Sales
# count    6.000000
# mean   229.500000
# std    100.899455
# min    120.000000
# 25%    143.000000
# 50%    221.500000
# 75%    315.750000
# max    350.000000

# %%
df.groupby('Company').describe()
# Out:
#         Sales
#         count   mean         std    min     25%    50%     75%    max
# Company
# FB        2.0  296.5   75.660426  243.0  269.75  296.5  323.25  350.0
# GOOG      2.0  160.0   56.568542  120.0  140.00  160.0  180.00  200.0
# MSFT      2.0  232.0  152.735065  124.0  178.00  232.0  286.00  340.0

# %%
df.groupby('Company').describe()['Sales'].loc[['GOOG','MSFT'],['min','25%']]
# Out:
#            min    25%
# Company
# GOOG     120.0  140.0
# MSFT     124.0  178.0

# %%
df.groupby('Company').describe()
# Out:
#         Sales
#         count   mean         std    min     25%    50%     75%    max
# Company
# FB        2.0  296.5   75.660426  243.0  269.75  296.5  323.25  350.0
# GOOG      2.0  160.0   56.568542  120.0  140.00  160.0  180.00  200.0
# MSFT      2.0  232.0  152.735065  124.0  178.00  232.0  286.00  340.0

# %%
df.groupby('Company').describe().loc['GOOG']
# Out:
# Sales  count      2.000000
#        mean     160.000000
#        std       56.568542
#        min      120.000000
#        25%      140.000000
#        50%      160.000000
#        75%      180.000000
#        max      200.000000
# Name: GOOG, dtype: float64

# %%
df.groupby('Company').describe().loc['GOOG']
# Out:
# count      2.000000
# mean     160.000000
# std       56.568542
# min      120.000000
# 25%      140.000000
# 50%      160.000000
# 75%      180.000000
# max      200.000000
# Name: GOOG, dtype: float64

# %%
df.groupby('Company').describe().loc['GOOG']['Sales']['std']
# Out:
# 56.568542494923804

# %%
df1=pd.DataFrame({'K1':["A","B","C"],
                'K2':["B","C","D"],
                'K3':['A',"B","D"]})
df1
# Out:
#   K1 K2 K3
# 0  A  B  A
# 1  B  C  B
# 2  C  D  D

# %%
df2=pd.DataFrame({'K1':["a","b","c"],
                'K2':["b","c","d"],
                'K3':['a',"b","d"]})
df2
# Out:
#   K1 K2 K3
# 0  a  b  a
# 1  b  c  b
# 2  c  d  d

# %%
df3=pd.DataFrame({'k1':["A","B","C"],
                'k2':["B","C","D"],
                'k3':['A',"B","D"]})
df3
# Out:
#   k1 k2 k3
# 0  A  B  A
# 1  B  C  B
# 2  C  D  D

# %%
df_cat1=pd.concat([df1,df2,df3])

# %%
df_cat1
# Out:
#     K1   K2   K3   k1   k2   k3
# 0    A    B    A  NaN  NaN  NaN
# 1    B    C    B  NaN  NaN  NaN
# 2    C    D    D  NaN  NaN  NaN
# 0    a    b    a  NaN  NaN  NaN
# 1    b    c    b  NaN  NaN  NaN
# 2    c    d    d  NaN  NaN  NaN
# 0  NaN  NaN  NaN    A    B    A
# 1  NaN  NaN  NaN    B    C    B
# 2  NaN  NaN  NaN    C    D    D

# %%
df_cat1=pd.concat([df1,df2,df3],axis=1)

# %%
df_cat1
# Out:
#   K1 K2 K3 K1 K2 K3 k1 k2 k3
# 0  A  B  A  a  b  a  A  B  A
# 1  B  C  B  b  c  b  B  C  B
# 2  C  D  D  c  d  d  C  D  D

# %%
import numpy as np
dir(np)
# Out:
# ['ALLOW_THREADS',
#  'AxisError',
#  'BUFSIZE',
#  'CLIP',
#  'ComplexWarning',
#  'DataSource',
#  'ERR_CALL',
#  'ERR_DEFAULT',
#  'ERR_IGNORE',
#  'ERR_LOG',
#  'ERR_PRINT',
#  'ERR_RAISE',
#  'ERR_WARN',
#  'FLOATING_POINT_SUPPORT',
#  'FPE_DIVIDEBYZERO',
#  'FPE_INVALID',
#  'FPE_OVERFLOW',
#  'FPE_UNDERFLOW',
#  'False_',
#  'Inf',
#  'Infinity',
#  'MAXDIMS',
#  'MAY_SHARE_BOUNDS',
#  'MAY_SHARE_EXACT',
#  'MachAr',
#  'ModuleDeprecationWarning',
#  'NAN',
#  'NINF',
#  'NZERO',
#  'NaN',
#  'PINF',
#  'PZERO',
#  'RAISE',
#  'RankWarning',
#  'SHIFT_DIVIDEBYZERO',
#  'SHIFT_INVALID',
#  'SHIFT_OVERFLOW',
#  'SHIFT_UNDERFLOW',
#  'ScalarType',
#  'Tester',
#  'TooHardError',
#  'True_',
#  'UFUNC_BUFSIZE_DEFAULT',
#  'UFUNC_PYVALS_NAME',
#  'VisibleDeprecationWarning',
#  'WRAP',
#  '_NoValue',
#  '_UFUNC_API',
#  '__NUMPY_SETUP__',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__config__',
#  '__dir__',
#  '__doc__',
#  '__file__',
#  '__getattr__',
# ...

# %%
dir(pd)
# Out:
# ['BooleanDtype',
#  'Categorical',
#  'CategoricalDtype',
#  'CategoricalIndex',
#  'DataFrame',
#  'DateOffset',
#  'DatetimeIndex',
#  'DatetimeTZDtype',
#  'ExcelFile',
#  'ExcelWriter',
#  'Float64Index',
#  'Grouper',
#  'HDFStore',
#  'Index',
#  'IndexSlice',
#  'Int16Dtype',
#  'Int32Dtype',
#  'Int64Dtype',
#  'Int64Index',
#  'Int8Dtype',
#  'Interval',
#  'IntervalDtype',
#  'IntervalIndex',
#  'MultiIndex',
#  'NA',
#  'NaT',
#  'NamedAgg',
#  'Period',
#  'PeriodDtype',
#  'PeriodIndex',
#  'RangeIndex',
#  'Series',
#  'SparseDtype',
#  'StringDtype',
#  'Timedelta',
#  'TimedeltaIndex',
#  'Timestamp',
#  'UInt16Dtype',
#  'UInt32Dtype',
#  'UInt64Dtype',
#  'UInt64Index',
#  'UInt8Dtype',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__docformat__',
#  '__file__',
#  '__getattr__',
#  '__git_version__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '_config',
#  '_hashtable',
#  '_lib',
#  '_libs',
# ...
